# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("TestDataset.csv")
df.head()
# Out:
#    ID                        Hostel_name
# 0   0                   SMP Group of PGs  \
# 1   1     Royal New Luxury PG for Ladies
# 2   2                  OM Sai Lakshmi PG
# 3   3  The Beehive Hostel Luxury mens PG
# 4   4            ELITE GIRLS PG / HOSTEL
#
#                                              address   pincode   latitude
# 0  41, 3rd Cross Road,opposite to metro piller no...  560068.0  12.882913  \
# 1  ROYAL PG, 10TH CROSS, NEAR SAI BABA TEMPLE,, B...  560070.0  12.898757
# 2  MegaMart, #1596/1, Amma Kodava Samaj, 27th cro...  560070.0  12.924003
# 3  2237, 23rd Cross Rd, next to Karnataka Grameen...  560111.0  12.924089
# 4  7, 3rd Cross Rd, near Dayananda Sagar college ...  560005.0  12.910611
#
#    longitude  review  Rating  wifi   ac  laundry  security  price
# 0  77.546050     NaN     4.4   0.0  1.0      1.0       0.0   4500
# 1  77.628021     NaN     4.0   1.0  1.0      1.0       1.0   3000
# 2  77.560701     NaN     5.0   1.0  1.0      1.0       1.0   5000
# 3  77.571722     NaN     4.4   NaN  NaN      NaN       NaN   6000
# 4  77.564789     NaN     4.9   NaN  NaN      NaN       NaN   5700

# %%
def Add_review(df):
    for i in range(len(df)-1):
        if float(df.Rating[i])>4.5:
            df.review[i]="good"
        elif  float(df.Rating[i])<4.5 or float(df.Rating[i])>3.5:
            df.review[i]="average"
        else:
            df.review[i]="bad"

# %%
Add_review(df)
df.head(10)
import matplotlib.pyplot as plt
plt.scatter(df["latitude"],df["longitude"])
plt.show()
# Out:
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3500748192.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.review[i]="average"

# %%
df['wifi'].isnull().sum()
# Out:
# 94

# %%
def Add_ammenities(df):
   
    for i in range(len(df)):
        if int(df.price[i])>=5000:
            df.ac[i]=1
            df.wifi[i]=1
            df.laundry[i]=1
            df.security[i]=1
        else:
            df.ac[i]=0
            df.wifi[i]=1
            df.laundry[i]=0
            df.security[i]=1

# %%
Add_ammenities(df)
df.head(10)
# Out:
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=0
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=0
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=0
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=0
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=0
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=0
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=0
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=0
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=0
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=0
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=0
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=0
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=0
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=0
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=0
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=0
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=0
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=0
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=0
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=0
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=0
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=0
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.ac[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.wifi[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.laundry[i]=1
# C:\Users\lahar\AppData\Local\Temp\ipykernel_10880\3051163714.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.security[i]=1
#    ID                                  Hostel_name
# 0   0                             SMP Group of PGs  \
# 1   1               Royal New Luxury PG for Ladies
# 2   2                            OM Sai Lakshmi PG
# 3   3            The Beehive Hostel Luxury mens PG
# 4   4                      ELITE GIRLS PG / HOSTEL
# 5   5                       home town paying guest
# 6   6                              Rentorio Hostel
# 7   7  Covie Bannerghatta 185 Paying Guest/Hostels
# 8   8                                        SA PG
# 9   9                                 Hive Hostels
#
#                                              address   pincode   latitude
# 0  41, 3rd Cross Road,opposite to metro piller no...  560068.0  12.882913  \
# 1  ROYAL PG, 10TH CROSS, NEAR SAI BABA TEMPLE,, B...  560070.0  12.898757
# 2  MegaMart, #1596/1, Amma Kodava Samaj, 27th cro...  560070.0  12.924003
# 3  2237, 23rd Cross Rd, next to Karnataka Grameen...  560111.0  12.924089
# 4  7, 3rd Cross Rd, near Dayananda Sagar college ...  560005.0  12.910611
# 5  18, Buddha Vihara Rd, above The Paan Studio, P...  560016.0  12.996492
# 6  1st Main Rd, Bannerghatta Main Rd, Pai Layout,...  560076.0  12.881288
# 7  113, Bannerghatta Main Rd, Madhuban Colony, Hu...  560041.0  12.875666
# 8  #76,/1-4 30 th cross 4th T block Swagat main R...  560076.0  12.930526
# 9  No. 10 - 11, Hive Hostels, Bannerghatta Main R...  560076.0  12.878150
#
#    longitude   review  Rating  wifi   ac  laundry  security  price
# 0  77.546050  average     4.4   1.0  0.0      0.0       1.0   4500
# 1  77.628021  average     4.0   1.0  0.0      0.0       1.0   3000
# 2  77.560701     good     5.0   1.0  1.0      1.0       1.0   5000
# 3  77.571722  average     4.4   1.0  1.0      1.0       1.0   6000
# 4  77.564789     good     4.9   1.0  1.0      1.0       1.0   5700
# 5  77.617142  average     4.2   1.0  1.0      1.0       1.0   6500
# 6  77.596427     good     5.0   1.0  1.0      1.0       1.0   8000
# 7  77.603822     good     5.0   1.0  1.0      1.0       1.0  12000
# 8  77.595155     good     5.0   1.0  1.0      1.0       1.0   6500
# 9  77.597746     good     4.8   1.0  1.0      1.0       1.0   5000

# %%
df.wifi.isnull().sum()
df.head(30)
# Out:
#     ID                                  Hostel_name
# 0    0                             SMP Group of PGs  \
# 1    1               Royal New Luxury PG for Ladies
# 2    2                            OM Sai Lakshmi PG
# 3    3            The Beehive Hostel Luxury mens PG
# 4    4                      ELITE GIRLS PG / HOSTEL
# 5    5                       home town paying guest
# 6    6                              Rentorio Hostel
# 7    7  Covie Bannerghatta 185 Paying Guest/Hostels
# 8    8                                        SA PG
# 9    9                                 Hive Hostels
# 10  10                             Abuzz Oxfordcaps
# 11  11           Sudarshan Luxury Living - Hulimavu
# 12  12                        Shivrang PG For Gents
# 13  13                   New Sri Vaishnavi Gents Pg
# 14  14                                  zolo icarus
# 15  15              Amma Ladies PG, Water tank road
# 16  17                   Shree Nideshwara Ladies Pg
# 17  18               Sri Balaji Luxurious Ladies Pg
# 18  19            SS LUXURY FOR GENTS AND LADIES PG
# 19  20                         Ss Comforts Gents Pg
# 20  21                      Fourth Pg Accommodation
# 21  23                           My Home Pg For Men
# 22  24                               ATITHI BOYS PG
# 23  25                      ELITE GIRLS PG / HOSTEL
# 24  26                            Lohitha Girl's PG
# 25  27                              Anagha Girls PG
# 26  28                             Ganapa's Boys PG
# 27  29                                SAGAR BOYS PG
# 28  30                             Yashoda Girls PG
# 29  31                              Anagha Girls PG
#
#                                               address   pincode   latitude
# 0   41, 3rd Cross Road,opposite to metro piller no...  560068.0  12.882913  \
# 1   ROYAL PG, 10TH CROSS, NEAR SAI BABA TEMPLE,, B...  560070.0  12.898757
# 2   MegaMart, #1596/1, Amma Kodava Samaj, 27th cro...  560070.0  12.924003
# 3   2237, 23rd Cross Rd, next to Karnataka Grameen...  560111.0  12.924089
# 4   7, 3rd Cross Rd, near Dayananda Sagar college ...  560005.0  12.910611
# 5   18, Buddha Vihara Rd, above The Paan Studio, P...  560016.0  12.996492
# 6   1st Main Rd, Bannerghatta Main Rd, Pai Layout,...  560076.0  12.881288
# 7   113, Bannerghatta Main Rd, Madhuban Colony, Hu...  560041.0  12.875666
# 8   #76,/1-4 30 th cross 4th T block Swagat main R...  560076.0  12.930526
# 9   No. 10 - 11, Hive Hostels, Bannerghatta Main R...  560076.0  12.878150
# 10  85/1, First Cross, Bannerghatta Main Rd, Hulim...  560076.0  13.927473
# 11  arch, no 9 2nd cross thimmareddy layout, Banne...  560062.0  12.883179
# 12  37/40, 3rd Main Road, 3rd Cross Rd, Srinidhi L...  560078.0  12.883786
# 13  metro station, ##2052/28-29e, jothi layout, op...  560078.0  12.896880
# 14  17, Beereshwara Nagar, Chunchgatta, Phase 7, J...  560085.0  12.889081
# 15  No.3006, Shobha Nilayam, VBN Co Operative Soci...  560078.0  12.931887
# 16  No.04 23rd Main, 1st Cross Marenhalli, Jp Naga...  560078.0  12.916187
# 17  No 26, 22nd Main Road, Jp Nagar 2nd Phase, Ban...  560076.0  12.914160
# 18  No 58, 1st Stage, 1st Cross, Govinda Reddy Lay...  560076.0  12.891525
# 19  No 33/111, Eastern Portion, 7th Cross, Bilekah...  560011.0  12.901458
# 20  No.400, 30th Cross, 8th B Main Road, Jayanagar...  560004.0  12.928980
# 21  No.31/50, Netaji Road, Tata Silk Farm Road, T....  560078.0  12.934960
# 22  1st Stage, Kumaraswamy Layout, Bengaluru, Karn...  560111.0  12.896539
# 23  7, 3rd Cross Rd, near Dayananda Sagar college ...  560078.0  12.940840
# 24  1555, 6th Cross Rd, 1st Stage, Kumaraswamy Lay...  560078.0  12.927456
# 25  36-37, 2nd Cross ,Teachers Colony, near Dayana...  560078.0  12.972960
# 26  Agasthya Arcade, 3rd Cross, near Dayanand Saga...  560078.0  12.972008
# 27  WH68+5PW, Sagar Boys PG, opposite Dayanand sag...  560078.0  12.982714
# 28  WH58+H2C, 7th Cross Rd, 1st Stage, Kumaraswamy...  560078.0  12.985390
# 29  36-37, 2nd Cross ,Teachers Colony, near Dayana...  560078.0  12.913842
#
#     longitude   review  Rating  wifi   ac  laundry  security  price
# 0   77.546050  average     4.4   1.0  0.0      0.0       1.0   4500
# 1   77.628021  average     4.0   1.0  0.0      0.0       1.0   3000
# 2   77.560701     good     5.0   1.0  1.0      1.0       1.0   5000
# 3   77.571722  average     4.4   1.0  1.0      1.0       1.0   6000
# 4   77.564789     good     4.9   1.0  1.0      1.0       1.0   5700
# 5   77.617142  average     4.2   1.0  1.0      1.0       1.0   6500
# 6   77.596427     good     5.0   1.0  1.0      1.0       1.0   8000
# 7   77.603822     good     5.0   1.0  1.0      1.0       1.0  12000
# 8   77.595155     good     5.0   1.0  1.0      1.0       1.0   6500
# 9   77.597746     good     4.8   1.0  1.0      1.0       1.0   5000
# 10  77.674873  average     4.1   1.0  0.0      0.0       1.0   3500
# 11  77.594839  average     3.7   1.0  1.0      1.0       1.0   8000
# 12  77.572320  average     4.2   1.0  1.0      1.0       1.0   5000
# 13  77.571118  average     3.7   1.0  1.0      1.0       1.0   5000
# 14  77.573159  average     4.0   1.0  1.0      1.0       1.0  10000
# 15  77.546331  average     4.0   1.0  1.0      1.0       1.0  10000
# 16  77.586398  average     4.5   1.0  1.0      1.0       1.0   5000
# 17  77.585762     good     4.9   1.0  1.0      1.0       1.0   5000
# 18  77.594052  average     3.9   1.0  0.0      0.0       1.0   4000
# 19  77.601162     good     4.9   1.0  1.0      1.0       1.0   6000
# 20  77.582669  average     3.9   1.0  1.0      1.0       1.0   7000
# 21  77.571541  average     3.8   1.0  1.0      1.0       1.0   5000
# 22  77.582943  average     4.1   1.0  1.0      1.0       1.0   5000
# 23  77.582292     good     4.9   1.0  0.0      0.0       1.0   4700
# 24  77.558946     good     4.6   1.0  1.0      1.0       1.0   6000
# 25  77.556199     good     4.9   1.0  1.0      1.0       1.0   7000
# 26  77.549597     good     4.6   1.0  1.0      1.0       1.0   5000
# 27  77.572943  average     3.8   1.0  0.0      0.0       1.0   4500
# 28  77.537237  average     4.1   1.0  1.0      1.0       1.0   5500
# 29  77.570555     good     4.9   1.0  1.0      1.0       1.0  10000

# %%
df1=df
df1.to_csv("HostelCluster.csv")

# %%
# Import required libraries
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score

features = ['latitude', 'longitude', 'price', 'Rating', 'wifi', 'ac', 'laundry', 'security']
#features =	["latitude"	,"longitude"	,	"Rating",	"wifi",	"ac",	"laundry",	"security"	,"price"]

# Preprocess data
X = df1[features]
#X = pd.get_dummies(X, columns=['review'])

# print(X.head())

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Determine optimal number of clusters
silhouette_scores = []
for n_clusters in range(2, 10):
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    cluster_labels = kmeans.fit_predict(X_scaled)
    silhouette_scores.append(silhouette_score(X_scaled, cluster_labels))
    

optimal_n_clusters = np.argmax(silhouette_scores)+2
# print(silhouette_scores)
# print(optimal_n_clusters)



# Perform clustering
kmeans = KMeans(n_clusters=4, random_state=42)
cluster_labels = kmeans.fit_predict(X_scaled)

# Add cluster labels to original dataset
df1['cluster'] = cluster_labels
def recommend_hostels(latitude, longitude, price, wifi,ac,laundry, security,Rating):
    user_input = pd.DataFrame({
        'latitude': [latitude],
        'longitude': [longitude],
        'price': [price],
        'Rating':[Rating],
        'wifi': [wifi],
        'ac': [ac],
        'laundry': [laundry],
        'security': [security]
    })
    #user_input = pd.get_dummies(user_input, columns=['wifi', 'ac', 'laundry', 'security'])
    user_input_scaled = scaler.transform(user_input)
    user_cluster = kmeans.predict(user_input_scaled)[0]
   
    recommended_hostels = df1[df1['cluster'] == user_cluster].sort_values('Rating', ascending=False)

    

    return recommended_hostels[['Hostel_name', 'price', 'Rating','latitude','longitude']]

# Example usage



recommend_hostels(latitude=12.8369852, longitude=77.985, price=8000, wifi= 0, ac=0, laundry= 1, security=1,Rating=3.7)
# Out:
#                            Hostel_name  price  Rating   latitude  longitude
# 2                    OM Sai Lakshmi PG   5000     5.0  12.924003  77.560701
# 8                                SA PG   6500     5.0  12.930526  77.595155
# 37                   Venkateshwara P G   6000     5.0  12.937571  77.558830
# 17      Sri Balaji Luxurious Ladies Pg   5000     4.9  12.914160  77.585762
# 87                             Star PG   6000     4.9  12.906051  77.603864
# 85                    S A PG FOR GENTS   7000     4.9  12.887165  77.600383
# 75                     Sri Vinayaka PG   5000     4.9  12.900858  77.586444
# 25                     Anagha Girls PG   7000     4.9  12.972960  77.556199
# 19                Ss Comforts Gents Pg   6000     4.9  12.901458  77.601162
# 96            Sai Eshwar Pg For Ladies   6000     4.9  12.918059  77.594514
# 4              ELITE GIRLS PG / HOSTEL   5700     4.9  12.910611  77.564789
# 41           Pg ACCOMMODATION for boys   6000     4.8  12.912674  77.562989
# 9                         Hive Hostels   5000     4.8  12.878150  77.597746
# 71             SLN Homes Ladies Hostel   5000     4.8  12.882682  77.595498
# 84                    Anagha Ladies PG   5000     4.7  12.881469  77.597458
# 24                   Lohitha Girl's PG   6000     4.6  12.927456  77.558946
# 26                    Ganapa's Boys PG   5000     4.6  12.972008  77.549597
# 36           Flourish Luxury Ladies Pg   7000     4.5  12.912893  77.570372
# 92         Shree Bhargavi Luxurious PG   7000     4.5  12.919553  77.595122
# 68                    Vbs Pg For Gents   7000     4.5  12.913993  77.594890
# 60                Good Lands Luxury Pg   6000     4.5  12.923917  77.505863
# 53                          RN Boys Pg   5000     4.5  12.911782  77.566611
# 16          Shree Nideshwara Ladies Pg   5000     4.5  12.916187  77.586398
# 95                   KEERTHI LADIES PG   5000     4.4  12.925678  77.572488
# 38   The Beehive Hostel Luxury mens PG   6500     4.4  12.924207  77.573855
# 3    The Beehive Hostel Luxury mens PG   6000     4.4  12.924089  77.571722
# 47                   Durga PG & Hostel   6500     4.4  12.930750  77.571900
# 81      Shri Shyam Vaishnavi Gents P G   5500     4.4  12.910470  77.581661
# 39     myroomie-Erica Girls PG / Hoste   7000     4.3  12.914347  77.569769
# 46         Jayanthi Luxury PG for Girl   5000     4.3  12.925647  77.580397
# 52           Flourish Paying Guest For   6000     4.3  12.908376  77.572998
# 32          Keerthi sai nest ladies pg   6500     4.3  12.906551  77.580018
# 49                 Nandana Organics Pg   5000     4.2  12.883001  77.546726
# 12               Shivrang PG For Gents   5000     4.2  12.883786  77.572320
# 30          Stanza Living Anamur House   6000     4.2  12.912169  77.571156
# 67  Adya Mansions (Best PG for Ladies)   6000     4.2  12.935432  77.559049
# 5               home town paying guest   6500     4.2  12.996492  77.617142
# 33                         JP Nagar PG   5500     4.1  12.905447  77.585884
# 28                    Yashoda Girls PG   5500     4.1  12.985390  77.537237
# 50                    SMP Paying Guest   5500     4.1  12.885729  77.546965
# 22                      ATITHI BOYS PG   5000     4.1  12.896539  77.582943
# 76                      Lakshmi Villas   5000     4.1  12.902684  77.584641
# 58                 SR2 Galaxy PG Girls   5000     4.0  12.894493  77.577142
# 48                         Rajmahal Pg   5000     4.0  12.881418  77.543419
# 91            Sri Nimishamba Ladies Pg   6000     3.9  12.918439  77.580637
# 20             Fourth Pg Accommodation   7000     3.9  12.928980  77.582669
# 35                      Skanda Boys PG   5500     3.9  12.902706  77.582411
# 31          Paradise PG For Boys & Men   5600     3.9  12.906893  77.565861
# 44       White House Women's Residence   7000     3.9  12.931496  77.573466
# 80              Karnataka Paying Guest   5000     3.8  12.903698  77.582105
# 64           Hema PG For Men and Women   5000     3.8  12.930673  77.514033
# 21                  My Home Pg For Men   5000     3.8  12.934960  77.571541
# 77              Sri Ram Sri Lakshmi Pg   5400     3.7  12.918062  77.586066
# 13          New Sri Vaishnavi Gents Pg   5000     3.7  12.896880  77.571118
# 11  Sudarshan Luxury Living - Hulimavu   8000     3.7  12.883179  77.594839
# 89             Slv Ragigudda Ladies Pg   5000     3.6  12.915420  77.594746
# 66                Akshaya PG for Men's   5000     3.0  12.933524  77.544679

# %%
import numpy as nm    
import matplotlib.pyplot as mtp    
import pandas as pd 
from sklearn.cluster import KMeans  
wcss_list= []  #Initializing the list for the values of WCSS  
  
#Using for loop for iterations from 1 to 10.  
for i in range(1, 11):  
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state= 42)  
    kmeans.fit(X)  
    wcss_list.append(kmeans.inertia_)  
# mtp.plot(range(1, 11), wcss_list)  
# mtp.title('The Elobw Method Graph')  
# mtp.xlabel('Number of clusters(k)')  
# mtp.ylabel('wcss_list')  
# mtp.show() 
# wcss_list
kmeans = KMeans(n_clusters=5, init='k-means++', random_state= 42)  
y_predict= kmeans.fit_predict(X) 
# mtp.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroid')   

print(kmeans.predict([[12.8369852,77.985,8000,1,1,1,0,4]]))
recommended_hostels = df1[df1['cluster'] == user_cluster].sort_values('Rating', ascending=False)
# Out:
# [0]
# C:\Users\lahar\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but KMeans was fitted with feature names
#   warnings.warn(

# %%
from joblib import dump
dump(kmeans,"./../savedmodels/model1.joblib")
# Out:
# ['./../savedmodels/model1.joblib']

# %%
# # Import required libraries
# import pandas as pd
# import numpy as np
# from sklearn.cluster import DBSCAN
# from sklearn.preprocessing import StandardScaler
# from sklearn.metrics import silhouette_score

# # Load data
# #data = pd.read_csv('hostel_pg_data.csv')

# # Select features
# features = ['latitude', 'longitutde', 'price', 'Rating', 'wifi', 'ac', 'laundry', 'security']

# # Preprocess data
# X = df1[features]
# #X = pd.get_dummies(X, columns=['wifi', 'ac', 'laundry', 'security'])
# scaler = StandardScaler()
# X_scaled = scaler.fit_transform(X)

# # Determine optimal values of eps and min_samples
# silhouette_scores = []
# for eps in np.arange(0.1, 2.1, 0.1):
#     for min_samples in range(2, 11):
#         dbscan = DBSCAN(eps=eps, min_samples=min_samples)
#         cluster_labels = dbscan.fit_predict(X_scaled)
#         if len(np.unique(cluster_labels)) > 1:
#             silhouette_scores.append((eps, min_samples, silhouette_score(X_scaled, cluster_labels)))

# optimal_params = max(silhouette_scores, key=lambda x: x[2])
# optimal_eps, optimal_min_samples, optimal_score = optimal_params


# print('Optimal eps:', optimal_eps)
# print('Optimal min_samples:', optimal_min_samples)
# print('Optimal silhouette score:', optimal_score)

# # Perform clustering
# dbscan = DBSCAN(eps=optimal_eps, min_samples=optimal_min_samples)
# cluster_labels = dbscan.fit_predict(X_scaled)

# # Add cluster labels to original dataset
# df1['cluster'] = cluster_labels

# # Define function to recommend hostels/PGs based on user's preferences
# def recommend_hostels(latitude, longitude, price, wifi,ac,laundry, security,Rating):
#     user_input = pd.DataFrame({
#         'latitude': [latitude],
#         'longitutde': [longitude],
#         'price': [price],
#         'Rating':[Rating],
#         'wifi': [wifi],
#         'ac': [ac],
#         'laundry': [laundry],
#         'security': [security]
#     })
#     user_input = pd.get_dummies(user_input)
#     user_input_scaled = scaler.transform(user_input)
#     user_cluster = dbscan.fit_predict(user_input_scaled)[0]
#     recommended_hostels = df1[df1['cluster'] == user_cluster].sort_values('Rating', ascending=False)
#     return recommended_hostels[['HostelName', 'price', 'Rating']]

# # Example usage
# print("dbscan Algorithm")
# recommend_hostels(latitude=12.87, longitude=78.9996, price=3000, wifi= 1, ac=1, laundry= 1, security=1,Rating=4.0)
